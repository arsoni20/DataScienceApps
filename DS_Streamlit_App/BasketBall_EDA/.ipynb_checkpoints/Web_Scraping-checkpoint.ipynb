# %%
import pandas as pd
year = 1995
url = "https://www.basketball-reference.com/leagues/NBA_" + str(year) + "_per_game.html"
html = pd.read_html(url, header = 0)
df = html[0]

# %%
df.head()
# Out:
#   Rk              Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0  1      Alaa Abdelnaby  PF  26  TOT  54   0   9.4  2.2   4.3  ...  .571
# 1  1      Alaa Abdelnaby  PF  26  SAC  51   0   9.3  2.3   4.3  ...  .571
# 2  1      Alaa Abdelnaby  PF  26  PHI   3   0  10.0  0.3   3.7  ...   NaN
# 3  2  Mahmoud Abdul-Rauf  PG  25  DEN  73  43  28.5  6.5  13.8  ...  .885
# 4  3       Michael Adams  PG  32  CHH  29   0  15.3  2.3   5.1  ...  .833
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 0  0.7  1.4  2.1  0.2  0.3  0.2  0.8  1.9   4.7
# 1  0.7  1.4  2.1  0.3  0.3  0.2  0.8  2.0   5.0
# 2  1.0  1.7  2.7  0.0  0.0  0.0  1.7  0.7   0.7
# 3  0.4  1.4  1.9  3.6  1.1  0.1  1.6  1.7  16.0
# 4  0.2  0.8  1.0  3.3  0.8  0.0  0.9  1.4   6.5
#
# [5 rows x 30 columns]

# %%
df[df.Age == 'Age'].index
# Out:
# Int64Index([ 22,  47,  70,  93, 116, 141, 164, 188, 211, 236, 259, 282, 305,
#             326, 349, 372, 395, 418, 439, 464],
#            dtype='int64')

# %%
df.query('Age=="Age"')
# Out:
#      Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB  \
# 22   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 47   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 70   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 93   Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 116  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 141  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 164  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 188  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 211  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 236  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# 259  Rk  Player  Pos  Age  Tm  G  GS  MP  FG  FGA  ...  FT%  ORB  DRB  TRB
# ...

# %%
df.iloc[22:24] # headers are getting repeated and we need to remove them
# Out:
#     Rk       Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB  \
# 22  Rk       Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   FT%  ORB
# 23  21  Dana Barros   PG   27  PHI  82  82  40.5  7.0  14.2  ...  .899  0.3
#
#     DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 22  DRB  TRB  AST  STL  BLK  TOV   PF   PTS
# 23  3.0  3.3  7.5  1.8  0.0  3.0  1.9  20.6
#
# [2 rows x 30 columns]
